# %% [markdown]
# functions are packages of code, and method calls combine two operations at once—an attribute fetch and a call:

# %%
L = [1,2,3]
L*5
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# **Attribute fetches**
# An expression of the form object.attribute means “fetch the value of attribute in object.”

# %% [markdown]
# **Call expressions**
# An expression of the form function(arguments) means “invoke the code of function, passing zero or more comma-separated argument objects to it, and return function’s result value.”

# %% [markdown]
# object.method(arguments)

# %%
S = 'spam'
result = S.find('m')#index of found subst
result
# Out:
# 3

# %%
S = 'spammy'
S =S[0:3] + 'xx' +S[ :1]
S
# Out:
# 'spaxxs'

# %%
S = 'spammy'
S = S.replace('mm', 'xx')
print(S)
# Out:
# spaxxy

# %%
P='Python Program'
P=P[3:7]*2
print(P)
P
# Out:
# hon hon
# 'hon hon '

# %%
'aa$bb$cc$dd'.replace('$', 'SPAM')
# Out:
# 'aaSPAMbbSPAMccSPAMdd'

# %% [markdown]
# S = 'xxxxSPAMxxxxSPAMxxxx'
# where = S.find('SPAM')
# where
# S = S[:where] + 'email' + S[(where+4):]
# S

# %%
S = 'xxxxSPAMxxxxSPAMxxxxSPAMxxxx'
S.replace('SPAM', 'Email',2)
# Out:
# 'xxxxEmailxxxxEmailxxxxSPAMxxxx'

# %%
S.replace('SPAM', 'Email', 1)
# Out:
# 'xxxxEmailxxxxSPAMxxxxSPAMxxxx'

# %%
S = 'spammy'
L = set(S)
L
# Out:
# {'a', 'm', 'p', 's', 'y'}

# %%
S = '/'.join(L)
S
# Out:
# 'm/s/p/a/y'

# %%
'#'.join(['eggs', 'sausage', 'ham', 'toast'])
# Out:
# 'eggs#sausage#ham#toast'

# %%
line = 'aaa bbb ccc'
col1 = line[0:3]
col3 = line[8:]
col1
# Out:
# 'aaa'

# %%
col3
# Out:
# 'ccc'

# %%
line = 'aa,abb,bccc'
cols = line.split('b')
cols
# Out:
# ['aa,a', '', ',', 'ccc']

# %%
line = 'bob,hacker,40'
line
# Out:
# 'bob,hacker,40'

# %%
print(line.split(','))
# Out:
# ['bob', 'hacker', '40']

# %%
line="iSPAMaSPAM student "
line
# Out:
# 'iSPAMaSPAM student '

# %%
l=line.split('SPAM')
print(l)
l=" ".join(l)
print(l)
# Out:
# ['i', 'a', ' student ']
# i a  student

# %%
line='string methods?'
line
# Out:
# 'string methods?'

# %%
line.strip('m ?')
# Out:
# 'string methods'

# %%
l=line.upper()
print(l)
l=l.lower()
print(l)
# Out:
# STRING METHODS?
# string methods?

# %%
a="ramesH"
a.isalpha()
# Out:
# True

# %%
line.endswith('?')
# Out:
# True

# %%
line.endswith('\n ')
# Out:
# False

# %%
line.startswith('s')
# Out:
# True

# %%
line.startswith('str')
# Out:
# True

# %%
line
# Out:
# 'string methods?'

# %%
line.find('ng')
# Out:
# 4

# %%
'met' in line
# Out:
# True

# %%
sub = 'Ni!\n'
# sub.endswith('\n')
len(sub)
# Out:
# 4

# %%
lin="str method"
lin[3::-1]
# Out:
# ' rts'

# %%
line
# Out:
# 'string methods?'

# %%
sub='ods\n'

# %%
line1='methods\n'

# %%
sub='ods\n'
line1='methods\n'
line1[-len(sub)::-1]
# Out:
# 'ohtem'

# %% [markdown]
# string.method(X, arguments)

# %%
S = 'a+b+c+'
x = S.replace('+', 'spam')
x
# Out:
# 'aspambspamcspam'

# %%
import math as m
'''def findroot(x):
  y=m.sqrt(x)
  return y'''
a=int(input("Enter a number:"))
sum=0
while(a>0):
  sum=sum+(a%10)
  a=a//10
print(sum)
print(m.factorial(a))
# Out:
# Enter a number:57
# 12
# 1

# %%
import datetime
a=datetime.datetime.today().date()
b=datetime.datetime.now().time()
print(a)
print(b)
# Out:
# 2022-07-29
# 06:09:56.230152

# %%
l=[1,2,3,4]
l2=[1,2,3]
if(l2>l):
  print('yes')
else:
  print("no")
# Out:
# no

# %%
def changer(a, b):
 a = 6
 b[0] = a
X=5
l=[1,2,3]
changer(X,l)
print(X)
print(l)
# Out:
# 5
# [6, 2, 3]

# %%
ip = input("Enter a sentence:")
words = ip.split('a')
print(words)
# Out:
# Enter a sentence:virat kohli
# ['vir', 't kohli']

# %%
x=input("Enter a number:")
sum=0

for i in x[1::3]:
  sum=sum+int(i)
print(sum)
# Out:
# Enter a number:123456
# 7

# %%
num = int(input("Enter a real number: "))
c=0
while num>0:
  num=num//10
  c+=1
print(c)
# Out:
# Enter a real number: 1234
# 4

# %%
x=input()
c=0
for i in x:
  c+=1
c
# Out:
# 445
# 3

# %%
import functools

# %%
map()
# Out:
# [3, 4]

# %%
def check(li,tu):
  x=[]
  for i in range(0,len(li)):
    for j in range(0,len(tu)):
      if li[i]==tu[j]:
        if li[i] not in x:
          x.append(li[i])
  return x
x=check([1,2,3,4,[1]],(3,4,[1],3,4,1))
x
# Out:
# [1, 3, 4, [1]]

# %%
class myClass:
 def setdata(self,val):
  self.data=val
 def getdata(self):
  print('myClass:'+str(self.data))
class newClass(myClass):
 def getdata(self):
  print('newClass:'+str(self.data))
x = myClass( )
y = newClass( )
myClass.data = 100
x.setdata(200)
y.newdata = 300
x.getdata( )
y.getdata( )
newClass.getdata(myClass)
print(list(x.__dict__.keys( )))
print(list(y.__dict__.keys( )))
# Out:
# myClass:200
# newClass:100
# newClass:100
# ['data']
# ['newdata']

# %%
grades=['a','a','s','b','c','d']
credits=[4,4,5,3,2,2]
grade_point={'s':10, 'a':9, 'b':8, 'c':7, 'd':6, 'f':0}
agp=0
for i in range(0,len(credits)):
  agp+=((grade_point[grades[i]]*credits[i])/20)
print(agp)
# Out:
# 8.6

# %%
a=int(input("Num1:"))
op=input("Op:")
b=int(input("Num2:"))
if op=='+':
  print(a+b)
elif op=='-':
  print(a-b)
elif op=='*':
  print(a*b)
elif op=='/':
  if b==0:
    print("Divide by zero err")
  else:
    print(a/b)
else:
  print("wrong operator")
# Out:
# Num1:5
# Op:/
# Num2:2
# 2.5

# %%
def ch(a,b):
  a=5
  b[0]=a
x=1
l=[1,2,3]
ch(x,l[:])
print(x)
print(l)
# Out:
# 1
# [5, 2, 3]

# %%
x=int(input())
print(x**(0.5))
# Out:
# 96
# 9.797958971132712

# %%
text='Be Positive'
text[::-2]
# Out:
# 'eiio B'

# %%
eiio B

# %%
x = range("goddamn it!")

#display x:
print(x)

#display the data type of x:
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1b4e1fb4d0e4> in <module>()
# ----> 1 x = range("goddamn it!")
#       2
#       3 #display x:
#       4 print(x)
#       5
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
num = int(input("Enter a number:"))
if num%2 == 0:
 print("%d is even number"%(num))
else:
 print("%d is odd number"%(num))
# Out:
# Enter a number:2
# 2 is even number
