# %% [markdown]
# Creating a Function

# %%
def fun():
  print("Welcome to NIE")

# %% [markdown]
# Calling a  Function

# %%
fun()
# Out:
# Welcome to NIE

# %%
def oddeven(x):
    if (x % 2 == 0):
        print("even")
    else:
        print("odd")
 
 
#  call the function
oddeven(5)
oddeven(6)
# Out:
# odd
# even

# %% [markdown]
# Types of arguments- Default argument

# %%
def fun1(x, y=20):
    print("x: ", x)
    print("y: ", y)
 
fun1(5)
# Out:
# x:  5
# y:  20

# %% [markdown]
# **Keyword arguments**
# allows the caller to specify the argument name with values so that caller does not need to remember the order of parameters.

# %%
def student(firstname, lastname):
    print(firstname, lastname)
 
 
# Keyword arguments
student(firstname='Jack', lastname='Jill')
student(lastname='Rose', firstname='vimple')
# Out:
# Jack Jill
# vimple Rose

# %% [markdown]
# **Variable length arguments**
# can pass a variable number of arguments to a function using special symbols. There are two special symbols:
#
# #*args (Non-Keyword Arguments)
# #**kwargs (Keyword Arguments)

# %% [markdown]
# Variable length non-keywords argument

# %%
def myFun(*argv):
    for arg in argv:
        print(arg)
 
 
myFun('Hello', 'Guys!!', 'Welcome','to', 'Python Programming !!')
# Out:
# Hello
# Guys!!
# Welcome
# to
# Python Programming !!

# %% [markdown]
# Variable length keyword arguments

# %%
def myFun1(**kwargs):
    for key, value in kwargs.items():
        print("%s--- %s" % (key, value))
 
 

myFun1(first='Hello', mid='Guys', last='Good morning')
# Out:
# first--- Hello
# mid--- Guys
# last--- Good morning

# %% [markdown]
# Adding Docstring to the function

# %%
def oddeven(x):
   """Function to check if the number is even or odd"""
  
   if (x % 2 == 0):
        print("even")
   else:
        print("odd")
 
 
# call the function
print(oddeven.__doc__)
# Out:
# Function to check if the number is even or odd
